# %% [markdown]
# # extracting features of 2018,19 movies from wikipedia

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### you will need lxml for fetching data from wikipedia
# ### install using command --> pip install lxml, pip3 install lxml
#
# ## lxml is a Python library which allows for easy handling of XML and HTML files, and can also be used for web scraping.
# ## web scraping is nothing but extracting data from a web page

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %% [markdown]
# ### just go to the link wo wikipedia given above. out of all the tables present on that webpage we only need the ones which contains data related to movies.
# ### there are four tables on that webpage that contains data for four quarters of the year.
# ### the index of those tables are 2,3,4,5

# %%
df1
# Out:
#     Opening  Opening.1                                Title  \
# 0   JANUARY          5              Insidious: The Last Key
# 1   JANUARY          5                     The Strange Ones
# 2   JANUARY          5                             Stratton
# 3   JANUARY         10                        Sweet Country
# 4   JANUARY         12                         The Commuter
# ..      ...        ...                                  ...
# 69    MARCH         29                     Ready Player One
# 70    MARCH         30               Tyler Perry's Acrimony
# 71    MARCH         30  God's Not Dead: A Light in Darkness
# 72    MARCH         30                               Gemini
# 73    MARCH         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2                                   Momentum Pictures
# ...

# %%
df2
# Out:
#    Opening  Opening.1                        Title  \
# 0    APRIL          6                A Quiet Place
# 1    APRIL          6                     Blockers
# 2    APRIL          6   You Were Never Really Here
# 3    APRIL          6               Chappaquiddick
# 4    APRIL          6                       Pandas
# ..     ...        ...                          ...
# 58    JUNE         28                The Domestics
# 59    JUNE         29  Sicario: Day of the Soldado
# 60    JUNE         29               Leave No Trace
# 61    JUNE         29                   Uncle Drew
# 62    JUNE         29            Woman Walks Ahead
#
#                                    Production company  \
# 0   Paramount Pictures / Platinum Dunes / Sunday N...
# 1   Universal Pictures / Good Universe / Point Gre...
# 2                                      Amazon Studios
# 3                               Entertainment Studios
# 4                        Warner Bros. Pictures / IMAX
# ...

# %%
df3
# Out:
#       Opening  Opening.1                                  Title  \
# 0        JULY          4                        The First Purge
# 1        JULY          6                   Ant-Man and the Wasp
# 2        JULY          6                    Sorry to Bother You
# 3        JULY          6                                Whitney
# 4        JULY         13  Hotel Transylvania 3: Summer Vacation
# ..        ...        ...                                    ...
# 62  SEPTEMBER         25           My Hero Academia: Two Heroes
# 63  SEPTEMBER         28                              Smallfoot
# 64  SEPTEMBER         28                           Night School
# 65  SEPTEMBER         28                  The Old Man & the Gun
# 66  SEPTEMBER         28                              Hell Fest
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / P...
# 1                                      Marvel Studios
# ...

# %%
df4
# Out:
#      Opening  Opening.1                       Title  \
# 0    OCTOBER          2            Power of the Air
# 1    OCTOBER          5                       Venom
# 2    OCTOBER          5              A Star Is Born
# 3    OCTOBER          5             The Hate U Give
# 4    OCTOBER         10            The Happy Prince
# ..       ...        ...                         ...
# 60  DECEMBER         25             Holmes & Watson
# 61  DECEMBER         25                        Vice
# 62  DECEMBER         25         On the Basis of Sex
# 63  DECEMBER         25                   Destroyer
# 64  DECEMBER         28  Black Mirror: Bandersnatch
#
#                               Production company  \
# 0                            Five & Two Pictures
# 1       Columbia Pictures / Marvel Entertainment
# 2                          Warner Bros. Pictures
# 3           20th Century Fox / Fox 2000 Pictures
# 4                         Sony Pictures Classics
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
# tmdbv3api --> A lightweight Python library for The Movie Database (TMDb) API. 
# The TMDb API is a resource for developers to integrate movie, TV show and cast data along with posters or movie fan art. themoviedb.org is a free and community edited database.

# JavaScript Object Notation (JSON) is a standardized format commonly used to transfer data as text that can be sent over a network. It's used by lots of APIs and Databases, and it's easy for both humans and machines to read. JSON represents objects as name/value pairs, just like a Python dictionary.

# Requests is a Python HTTP library, released under the Apache License 2.0. The goal of the project is to make HTTP requests simpler and more human-friendly. 

from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'd6ab700e0705e0b8b97c877c3d6ba145'

# %% [markdown]
# https://developers.themoviedb.org/3/getting-started/search-and-query-for-details
#
# this link shows some documentation on how to use the tmdb api and the library.
#
# 1. search --> search for a movie with its name in tmdb dataset
# 2. it will return an object containing the certain details of the movie.
# 3. query for details --> from there just fetch the id of this movie and then make another request for getting the entire details of the movie.

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...
# 265  Adam McKay (director/screenplay); Christian Ba...
# 266  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /home/anirudh/.local/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_2018['director_name']
# Out:
# 0            Adam Robitel
# 1        Lauren Wolkstein
# 2              Simon West
# 3        Warwick Thornton
# 4      Jaume Collet-Serra
#               ...
# 264            Etan Cohen
# 265            Adam McKay
# 266            Mimi Leder
# 267          Karyn Kusama
# 268           David Slade
# Name: director_name, Length: 269, dtype: object

# %%
df_2018['Cast and crew'][0]
# Out:
# 'Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Kirk Acevedo, Bruce Davison'

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /home/anirudh/.local/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...
# 265  Adam McKay (director/screenplay); Christian Ba...
# 266  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %% [markdown]
# ## extracting features of 2019 movies

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

df_2019 = df[['Title','Cast and crew','genres']]

df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /home/anirudh/.local/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 237  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 238            Greta Gerwig        Saoirse Ronan           Emma Watson
# 239              Sam Mendes        George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# ...

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

my_df
# Out:
#               director_name       actor_1_name            actor_2_name  \
# 0              Adam Robitel          Lin Shaye           Angus Sampson
# 1          Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2                Simon West     Dominic Cooper          Austin Stowell
# 3          Warwick Thornton        Bryan Brown               Sam Neill
# 4        Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                      ...                ...                     ...
# 506  Nick Bruno, Troy Quane         Will Smith             Tom Holland
# 507            Greta Gerwig      Saoirse Ronan             Emma Watson
# 508              Sam Mendes      George MacKay    Dean-Charles Chapman
# 509   Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 510         Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# ...

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5870  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5871            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5872              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5873   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5874         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           3
# movie_title      0
# comb             3
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_73566/788497093.py in <module>
# ----> 1 final_df.to_csv('../datasets/final_data.csv',index=False)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3461         )
#    3462
# -> 3463         return DataFrameRenderer(formatter).to_csv(
#    3464             path_or_buf,
#    3465             line_terminator=line_terminator,
#
# ...
